# %%
import pandas as pd

# %%
obj = pd.Series([3,4,7,12,80])
obj
# Out:
# 0     3
# 1     4
# 2     7
# 3    12
# 4    80
# dtype: int64

# %%
obj[obj>=5]
# Out:
# 2     7
# 3    12
# 4    80
# dtype: int64

# %%
obj+10
# Out:
# 0    13
# 1    14
# 2    17
# 3    22
# 4    90
# dtype: int64

# %%
states = {'punjab':45000, 'haryana':540000, 'himachal':65485435, 'up':894659}

# %%
obj2 = pd.Series(states)
obj2
# Out:
# punjab         45000
# haryana       540000
# himachal    65485435
# up            894659
# dtype: int64

# %%
states1 = {'punjab':45000, 'haryana':540000, 'himachal':65485435, 'uttrakhand':4594659}

# %%
obj3 = pd.Series(states1)
obj3
# Out:
# punjab           45000
# haryana         540000
# himachal      65485435
# uttrakhand     4594659
# dtype: int64

# %%
x = obj2 + obj3

# %%
x
# Out:
# haryana         1080000.0
# himachal      130970870.0
# punjab            90000.0
# up                    NaN
# uttrakhand            NaN
# dtype: float64

# %%
pd.isnull(x)
# Out:
# haryana       False
# himachal      False
# punjab        False
# up             True
# uttrakhand     True
# dtype: bool

# %% [markdown]
# # read_csv() to create data frame

# %%
df = pd.read_csv('nyc_weather.csv')

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20         3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN

# %%
df.tail(4)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN

# %%
# in this we will give the new name to the dataframe as x 

x = df.columns

# after giving the name we want the only 4 headings present in the x dataframe, we will do slicing 

a = x[1:4]

# %%
# now we will give new name to the dataframe y and we want only 10 rows
# from the present dataframe with the heading done in previous step

y = df[a].head(10)

# %%
y
# Out:
#    Temperature  DewPoint  Humidity
# 0           38        23        52
# 1           36        18        46
# 2           40        21        47
# 3           25         9        44
# 4           20         3        41
# 5           33         4        35
# 6           39        11        33
# 7           39        29        64
# 8           44        38        77
# 9           50        46        71

# %%
# in this we want to check the how much column and rows present in the dataframe y

y.shape
# Out:
# (10, 3)

# %%
# if want only the value present in the dataframe then we will use this function

y['Temperature']
# Out:
# 0    38
# 1    36
# 2    40
# 3    25
# 4    20
# 5    33
# 6    39
# 7    39
# 8    44
# 9    50
# Name: Temperature, dtype: int64

# %%
y.Temperature
# Out:
# 0    38
# 1    36
# 2    40
# 3    25
# 4    20
# 5    33
# 6    39
# 7    39
# 8    44
# 9    50
# Name: Temperature, dtype: int64

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20         3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
# in this we will check the data for which value is greater than 40 in temperature column
 
v = df[df.Temperature>40]

# %%
v
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 14   1/15/2016           43        31        62                 29.82
# 15   1/16/2016           47        37        70                 29.52
# 25   1/26/2016           43        29        56                 30.03
# 26   1/27/2016           41        22        45                 30.03
# 30   1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
# in this we will check the data for which value is greater than 50 in Humidity column

df[df.Humidity>50]
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 11  01-12-2016           35        15        53                 29.85
# 14   1/15/2016           43        31        62                 29.82
# 15   1/16/2016           47        37        70                 29.52
# 16   1/17/2016           36        23        66                 29.78
# 17   1/18/2016           25         6        53                 29.83
# 22   1/23/2016           26        21        78                 29.77
# 23   1/24/2016           28        11        53                 29.92
# 24   1/25/2016           34        18        54                 30.25
# ...

# %%
# if we want data from 'Events' give me all the days which are having 'Rain' in the events columns

s = df[['EST', 'Temperature', 'Events']][df.Events=='Rain']

# %%
s
# Out:
#            EST  Temperature Events
# 8   01-09-2016           44   Rain
# 9   01-10-2016           50   Rain
# 15   1/16/2016           47   Rain
# 26   1/27/2016           41   Rain

# %%
# in this give me data of temperature above than 45

s = df[['EST', 'Temperature', 'Events']][df.Events=='Rain']
s[s.Temperature>45]
# Out:
#            EST  Temperature Events
# 9   01-10-2016           50   Rain
# 15   1/16/2016           47   Rain

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20         3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
# print the maximum temperature present in the dataframe 


df.Temperature.max()
# Out:
# 50

# %%
# print the minimum temperature present in the dataframe

df.Temperature.min()
# Out:
# 20

# %%
s
# Out:
#            EST  Temperature Events
# 8   01-09-2016           44   Rain
# 9   01-10-2016           50   Rain
# 15   1/16/2016           47   Rain
# 26   1/27/2016           41   Rain

# %%
s.describe()
# Out:
#        Temperature
# count     4.000000
# mean     45.500000
# std       3.872983
# min      41.000000
# 25%      43.250000
# 50%      45.500000
# 75%      47.750000
# max      50.000000

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20         3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %% [markdown]
# ### display the record where the temperature is maximum

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  01-10-2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 9                4           NaN             1.8           7   Rain

# %%
# FOR MAKING AN INDEX WE WILL USE   set_index()  this function

df.set_index('EST')
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 01-01-2016           38        23        52                 30.03
# 01-02-2016           36        18        46                 30.02
# 01-03-2016           40        21        47                 29.86
# 01-04-2016           25         9        44                 30.05
# 01-05-2016           20         3        41                 30.57
# 01-06-2016           33         4        35                 30.50
# 01-07-2016           39        11        33                 30.28
# 01-08-2016           39        29        64                 30.20
# 01-09-2016           44        38        77                 30.16
# 01-10-2016           50        46        71                 29.59
# 01-11-2016           33         8        37                 29.92
# 01-12-2016           35        15        53                 29.85
# 1/13/2016            26         4        42                 29.94
# ...

# %%
v
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 14   1/15/2016           43        31        62                 29.82
# 15   1/16/2016           47        37        70                 29.52
# 25   1/26/2016           43        29        56                 30.03
# 26   1/27/2016           41        22        45                 30.03
# 30   1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
v.to_csv('v_csv')

# %%
# to skip the numbers of rows from the dataframe we will use the    skiprows()   functions in csv files 

p = pd.read_csv('v_csv',skiprows=2 , header = None, names=['a','b','c','d','e','f','g','h'])
p.head(5)
# Out:
#                    a   b      c   d    e     f  g     h
# 9  01-10-2016 50  46  71  29.59   4  NaN   1.8  7  Rain
# 14 1/15/2016  43  31  62  29.82   9  5.0     T  2   NaN
# 15 1/16/2016  47  37  70  29.52   8  7.0  0.24  7  Rain
# 25 1/26/2016  43  29  56  30.03  10  7.0     0  2   NaN
# 26 1/27/2016  41  22  45  30.03  10  7.0     T  3  Rain

# %%
v
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 14   1/15/2016           43        31        62                 29.82
# 15   1/16/2016           47        37        70                 29.52
# 25   1/26/2016           43        29        56                 30.03
# 26   1/27/2016           41        22        45                 30.03
# 30   1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
p = pd.read_csv('v_csv',skiprows=[1,3])

# %%
p
# Out:
#    Unnamed: 0         EST  Temperature  DewPoint  Humidity  \
# 0           9  01-10-2016           50        46        71
# 1          15   1/16/2016           47        37        70
# 2          25   1/26/2016           43        29        56
# 3          26   1/27/2016           41        22        45
# 4          30   1/31/2016           46        28        52
#
#    Sea Level PressureIn  VisibilityMiles  WindSpeedMPH PrecipitationIn  \
# 0                 29.59                4           NaN             1.8
# 1                 29.52                8           7.0            0.24
# 2                 30.03               10           7.0               0
# 3                 30.03               10           7.0               T
# 4                 29.90               10           5.0               0
#
#    CloudCover Events
# 0           7   Rain
# 1           7   Rain
# 2           2    NaN
# 3           3   Rain
# 4           0    NaN

# %%
v
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 14   1/15/2016           43        31        62                 29.82
# 15   1/16/2016           47        37        70                 29.52
# 25   1/26/2016           43        29        56                 30.03
# 26   1/27/2016           41        22        45                 30.03
# 30   1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
# it will give the how much rows you want it will that

p = pd.read_csv('v_csv',nrows=5)

# %%
p
# Out:
#    Unnamed: 0         EST  Temperature  DewPoint  Humidity  \
# 0           8  01-09-2016           44        38        77
# 1           9  01-10-2016           50        46        71
# 2          14   1/15/2016           43        31        62
# 3          15   1/16/2016           47        37        70
# 4          25   1/26/2016           43        29        56
#
#    Sea Level PressureIn  VisibilityMiles  WindSpeedMPH PrecipitationIn  \
# 0                 30.16                9           8.0               T
# 1                 29.59                4           NaN             1.8
# 2                 29.82                9           5.0               T
# 3                 29.52                8           7.0            0.24
# 4                 30.03               10           7.0               0
#
#    CloudCover Events
# 0           8   Rain
# 1           7   Rain
# 2           2    NaN
# 3           7   Rain
# 4           2    NaN

# %% [markdown]
# ###  To create a new csv file we will use  ' df.to_csv('xyz.csv') '
